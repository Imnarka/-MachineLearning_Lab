# %%
import os
import pandas as pd
import math

# %%
OPTION = 23
df = pd.read_csv(os.path.join(os.path.abspath('..'), './data/Data_laba_1_ML.csv')).iloc[34 * OPTION - 1: (34 * OPTION - 1) + 34]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 781          782         1       1
# 782          783         0       1
# 783          784         0       3
# 784          785         0       3
# 785          786         0       3
# 786          787         1       3
# 787          788         0       3
# 788          789         1       3
# 789          790         0       1
# 790          791         0       3
# 791          792         0       2
# 792          793         0       3
# 793          794         0       1
# 794          795         0       3
# 795          796         0       2
# 796          797         1       1
# 797          798         1       3
# 798          799         0       3
# 799          800         0       3
# 800          801         0       2
# 801          802         1       2
# 802          803         1       1
# 803          804         1       3
# 804          805         1       3
# 805          806         0       3
# 806          807         0       1
# 807          808         0       3
# 808          809         0       2
# 809          810         1       1
# 810          811         0       3
# 811          812         0       3
# 812          813         0       2
# 813          814         0       3
# 814          815         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.00      1
# 782                             Long, Mr. Milton Clyde    male  29.00      0
# 783                             Johnston, Mr. Andrew G    male    NaN      1
# 784                                   Ali, Mr. William    male  25.00      0
# 785                 Harmer, Mr. Abraham (David Lishin)    male  25.00      0
# 786                          Sjoblom, Miss. Anna Sofia  female  18.00      0
# 787                          Rice, Master. George Hugh    male   8.00      4
# 788                         Dean, Master. Bertram Vere    male   1.00      1
# 789                           Guggenheim, Mr. Benjamin    male  46.00      0
# 790                           Keane, Mr. Andrew "Andy"    male    NaN      0
# 791                                Gaskell, Mr. Alfred    male  16.00      0
# 792                            Sage, Miss. Stella Anna  female    NaN      8
# 793                           Hoyt, Mr. William Fisher    male    NaN      0
# 794                              Dantcheff, Mr. Ristiu    male  25.00      0
# 795                                 Otter, Mr. Richard    male  39.00      0
# 796                        Leader, Dr. Alice (Farnham)  female  49.00      0
# 797                                   Osman, Mrs. Mara  female  31.00      0
# 798                       Ibrahim Shawah, Mr. Yousseff    male  30.00      0
# 799  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female  30.00      1
# 800                               Ponesell, Mr. Martin    male  34.00      0
# 801        Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.00      1
# 802                Carter, Master. William Thornton II    male  11.00      1
# 803                    Thomas, Master. Assad Alexander    male   0.42      0
# 804                            Hedman, Mr. Oskar Arvid    male  27.00      0
# 805                          Johansson, Mr. Karl Johan    male  31.00      0
# 806                             Andrews, Mr. Thomas Jr    male  39.00      0
# 807                    Pettersson, Miss. Ellen Natalia  female  18.00      0
# 808                                  Meyer, Mr. August    male  39.00      0
# 809     Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.00      1
# 810                             Alexander, Mr. William    male  26.00      0
# 811                                  Lester, Mr. James    male  39.00      0
# 812                          Slemen, Mr. Richard James    male  35.00      0
# 813                 Andersson, Miss. Ebba Iris Alfrida  female   6.00      4
# 814                         Tomlin, Mr. Ernest Portage    male  30.50      0
#
#      Parch              Ticket      Fare    Cabin Embarked
# 781      0               17474   57.0000      B20        S
# 782      0              113501   30.0000       D6        S
# 783      2          W./C. 6607   23.4500      NaN        S
# 784      0  SOTON/O.Q. 3101312    7.0500      NaN        S
# 785      0              374887    7.2500      NaN        S
# 786      0             3101265    7.4958      NaN        S
# 787      1              382652   29.1250      NaN        Q
# 788      2           C.A. 2315   20.5750      NaN        S
# 789      0            PC 17593   79.2000  B82 B84        C
# 790      0               12460    7.7500      NaN        Q
# 791      0              239865   26.0000      NaN        S
# 792      2            CA. 2343   69.5500      NaN        S
# 793      0            PC 17600   30.6958      NaN        C
# 794      0              349203    7.8958      NaN        S
# 795      0               28213   13.0000      NaN        S
# 796      0               17465   25.9292      D17        S
# 797      0              349244    8.6833      NaN        S
# 798      0                2685    7.2292      NaN        C
# 799      1              345773   24.1500      NaN        S
# 800      0              250647   13.0000      NaN        S
# 801      1          C.A. 31921   26.2500      NaN        S
# 802      2              113760  120.0000  B96 B98        S
# 803      1                2625    8.5167      NaN        C
# 804      0              347089    6.9750      NaN        S
# 805      0              347063    7.7750      NaN        S
# 806      0              112050    0.0000      A36        S
# 807      0              347087    7.7750      NaN        S
# 808      0              248723   13.0000      NaN        S
# 809      0              113806   53.1000       E8        S
# 810      0                3474    7.8875      NaN        S
# 811      0           A/4 48871   24.1500      NaN        S
# 812      0               28206   10.5000      NaN        S
# 813      2              347082   31.2750      NaN        S
# 814      0              364499    8.0500      NaN        S

# %% [markdown]
# Вывести первые N строк датафрейма:

# %%
df.head(n=2) # по умолчанию 10
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 781          782         1       1  Dick, Mrs. Albert Adrian (Vera Gillespie)
# 782          783         0       1                     Long, Mr. Milton Clyde
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 781  female  17.0      1      0   17474  57.0   B20        S
# 782    male  29.0      0      0  113501  30.0    D6        S

# %% [markdown]
# Вывести "статискиу" датафрейма: среднее значение, стандартное отклонение, минимум и максимум, верхние значения первого и третьего квартиля и медиану по каждому столбцу

# %%
df.describe()
# Out:
#        PassengerId   Survived     Pclass        Age      SibSp      Parch  \
# count    34.000000  34.000000  34.000000  30.000000  34.000000  34.000000
# mean    798.500000   0.294118   2.352941  26.297333   0.676471   0.411765
# std       9.958246   0.462497   0.848612  12.420692   1.627800   0.743360
# min     782.000000   0.000000   1.000000   0.420000   0.000000   0.000000
# 25%     790.250000   0.000000   2.000000  18.000000   0.000000   0.000000
# 50%     798.500000   0.000000   3.000000  29.500000   0.000000   0.000000
# 75%     806.750000   1.000000   3.000000  33.750000   1.000000   0.750000
# max     815.000000   1.000000   3.000000  49.000000   8.000000   2.000000
#
#              Fare
# count   34.000000
# mean    24.125979
# std     25.243584
# min      0.000000
# 25%      7.803125
# 50%     13.000000
# 75%     28.406250
# max    120.000000

# %% [markdown]
# Запрос с условными операторами

# %%
df.query('Survived > 0')
# Out:
#      PassengerId  Survived  Pclass  \
# 781          782         1       1
# 786          787         1       3
# 788          789         1       3
# 796          797         1       1
# 797          798         1       3
# 801          802         1       2
# 802          803         1       1
# 803          804         1       3
# 804          805         1       3
# 809          810         1       1
#
#                                                Name     Sex    Age  SibSp  \
# 781       Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.00      1
# 786                       Sjoblom, Miss. Anna Sofia  female  18.00      0
# 788                      Dean, Master. Bertram Vere    male   1.00      1
# 796                     Leader, Dr. Alice (Farnham)  female  49.00      0
# 797                                Osman, Mrs. Mara  female  31.00      0
# 801     Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.00      1
# 802             Carter, Master. William Thornton II    male  11.00      1
# 803                 Thomas, Master. Assad Alexander    male   0.42      0
# 804                         Hedman, Mr. Oskar Arvid    male  27.00      0
# 809  Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.00      1
#
#      Parch      Ticket      Fare    Cabin Embarked
# 781      0       17474   57.0000      B20        S
# 786      0     3101265    7.4958      NaN        S
# 788      2   C.A. 2315   20.5750      NaN        S
# 796      0       17465   25.9292      D17        S
# 797      0      349244    8.6833      NaN        S
# 801      1  C.A. 31921   26.2500      NaN        S
# 802      2      113760  120.0000  B96 B98        S
# 803      1        2625    8.5167      NaN        C
# 804      0      347089    6.9750      NaN        S
# 809      0      113806   53.1000       E8        S

# %% [markdown]
# Группировка по столбцам c аггрегированием

# %%
df.groupby('Embarked').agg(sum).loc[:,"Survived"]
# Out:
# /tmp/ipykernel_1742/3638000176.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Embarked').agg(sum).loc[:,"Survived"]
# Embarked
# C    1
# Q    0
# S    9
# Name: Survived, dtype: int64

# %% [markdown]
# Выборки данных

# %%
print(df.iloc[4:6, 0:2]) # выбор по поизции
print(df.loc[:, 'Pclass':'Name']) # выбор по метке
# Out:
#      PassengerId  Survived
# 785          786         0
# 786          787         1
#      Pclass                                               Name
# 781       1          Dick, Mrs. Albert Adrian (Vera Gillespie)
# 782       1                             Long, Mr. Milton Clyde
# 783       3                             Johnston, Mr. Andrew G
# 784       3                                   Ali, Mr. William
# 785       3                 Harmer, Mr. Abraham (David Lishin)
# 786       3                          Sjoblom, Miss. Anna Sofia
# 787       3                          Rice, Master. George Hugh
# 788       3                         Dean, Master. Bertram Vere
# 789       1                           Guggenheim, Mr. Benjamin
# 790       3                           Keane, Mr. Andrew "Andy"
# 791       2                                Gaskell, Mr. Alfred
# 792       3                            Sage, Miss. Stella Anna
# 793       1                           Hoyt, Mr. William Fisher
# 794       3                              Dantcheff, Mr. Ristiu
# 795       2                                 Otter, Mr. Richard
# 796       1                        Leader, Dr. Alice (Farnham)
# 797       3                                   Osman, Mrs. Mara
# 798       3                       Ibrahim Shawah, Mr. Yousseff
# 799       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 800       2                               Ponesell, Mr. Martin
# 801       2        Collyer, Mrs. Harvey (Charlotte Annie Tate)
# 802       1                Carter, Master. William Thornton II
# 803       3                    Thomas, Master. Assad Alexander
# 804       3                            Hedman, Mr. Oskar Arvid
# 805       3                          Johansson, Mr. Karl Johan
# 806       1                             Andrews, Mr. Thomas Jr
# 807       3                    Pettersson, Miss. Ellen Natalia
# 808       2                                  Meyer, Mr. August
# 809       1     Chambers, Mrs. Norman Campbell (Bertha Griggs)
# 810       3                             Alexander, Mr. William
# 811       3                                  Lester, Mr. James
# 812       2                          Slemen, Mr. Richard James
# 813       3                 Andersson, Miss. Ebba Iris Alfrida
# 814       3                         Tomlin, Mr. Ernest Portage

# %% [markdown]
# Индексация

# %%
df.index
# Out:
# RangeIndex(start=781, stop=815, step=1)

# %% [markdown]
# Транспонирование

# %%
df.T
# Out:
#                                                    781  \
# PassengerId                                        782
# Survived                                             1
# Pclass                                               1
# Name         Dick, Mrs. Albert Adrian (Vera Gillespie)
# Sex                                             female
# Age                                               17.0
# SibSp                                                1
# Parch                                                0
# Ticket                                           17474
# Fare                                              57.0
# Cabin                                              B20
# Embarked                                             S
#
#                                 782                     783  \
# PassengerId                     783                     784
# Survived                          0                       0
# Pclass                            1                       3
# Name         Long, Mr. Milton Clyde  Johnston, Mr. Andrew G
# Sex                            male                    male
# Age                            29.0                     NaN
# SibSp                             0                       1
# Parch                             0                       2
# Ticket                       113501              W./C. 6607
# Fare                           30.0                   23.45
# Cabin                            D6                     NaN
# Embarked                          S                       S
#
#                             784                                 785  \
# PassengerId                 785                                 786
# Survived                      0                                   0
# Pclass                        3                                   3
# Name           Ali, Mr. William  Harmer, Mr. Abraham (David Lishin)
# Sex                        male                                male
# Age                        25.0                                25.0
# SibSp                         0                                   0
# Parch                         0                                   0
# Ticket       SOTON/O.Q. 3101312                              374887
# Fare                       7.05                                7.25
# Cabin                       NaN                                 NaN
# Embarked                      S                                   S
#
#                                    786                        787  \
# PassengerId                        787                        788
# Survived                             1                          0
# Pclass                               3                          3
# Name         Sjoblom, Miss. Anna Sofia  Rice, Master. George Hugh
# Sex                             female                       male
# Age                               18.0                        8.0
# SibSp                                0                          4
# Parch                                0                          1
# Ticket                         3101265                     382652
# Fare                            7.4958                     29.125
# Cabin                              NaN                        NaN
# Embarked                             S                          Q
#
#                                     788                       789  \
# PassengerId                         789                       790
# Survived                              1                         0
# Pclass                                3                         1
# Name         Dean, Master. Bertram Vere  Guggenheim, Mr. Benjamin
# Sex                                male                      male
# Age                                 1.0                      46.0
# SibSp                                 1                         0
# Parch                                 2                         0
# Ticket                        C.A. 2315                  PC 17593
# Fare                             20.575                      79.2
# Cabin                               NaN                   B82 B84
# Embarked                              S                         C
#
#                                   790  ...                        805  \
# PassengerId                       791  ...                        806
# Survived                            0  ...                          0
# Pclass                              3  ...                          3
# Name         Keane, Mr. Andrew "Andy"  ...  Johansson, Mr. Karl Johan
# Sex                              male  ...                       male
# Age                               NaN  ...                       31.0
# SibSp                               0  ...                          0
# Parch                               0  ...                          0
# Ticket                          12460  ...                     347063
# Fare                             7.75  ...                      7.775
# Cabin                             NaN  ...                        NaN
# Embarked                            Q  ...                          S
#
#                                 806                              807  \
# PassengerId                     807                              808
# Survived                          0                                0
# Pclass                            1                                3
# Name         Andrews, Mr. Thomas Jr  Pettersson, Miss. Ellen Natalia
# Sex                            male                           female
# Age                            39.0                             18.0
# SibSp                             0                                0
# Parch                             0                                0
# Ticket                       112050                           347087
# Fare                            0.0                            7.775
# Cabin                           A36                              NaN
# Embarked                          S                                S
#
#                            808  \
# PassengerId                809
# Survived                     0
# Pclass                       2
# Name         Meyer, Mr. August
# Sex                       male
# Age                       39.0
# SibSp                        0
# Parch                        0
# Ticket                  248723
# Fare                      13.0
# Cabin                      NaN
# Embarked                     S
#
#                                                         809  \
# PassengerId                                             810
# Survived                                                  1
# Pclass                                                    1
# Name         Chambers, Mrs. Norman Campbell (Bertha Griggs)
# Sex                                                  female
# Age                                                    33.0
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113806
# Fare                                                   53.1
# Cabin                                                    E8
# Embarked                                                  S
#
#                                 810                811  \
# PassengerId                     811                812
# Survived                          0                  0
# Pclass                            3                  3
# Name         Alexander, Mr. William  Lester, Mr. James
# Sex                            male               male
# Age                            26.0               39.0
# SibSp                             0                  0
# Parch                             0                  0
# Ticket                         3474          A/4 48871
# Fare                         7.8875              24.15
# Cabin                           NaN                NaN
# Embarked                          S                  S
#
#                                    812                                 813  \
# PassengerId                        813                                 814
# Survived                             0                                   0
# Pclass                               2                                   3
# Name         Slemen, Mr. Richard James  Andersson, Miss. Ebba Iris Alfrida
# Sex                               male                              female
# Age                               35.0                                 6.0
# SibSp                                0                                   4
# Parch                                0                                   2
# Ticket                           28206                              347082
# Fare                              10.5                              31.275
# Cabin                              NaN                                 NaN
# Embarked                             S                                   S
#
#                                     814
# PassengerId                         815
# Survived                              0
# Pclass                                3
# Name         Tomlin, Mr. Ernest Portage
# Sex                                male
# Age                                30.5
# SibSp                                 0
# Parch                                 0
# Ticket                           364499
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
#
# [12 rows x 34 columns]

# %%
# сколько пропущенных значений в столбце Cabin?
print(df['Cabin'].isnull().sum())
# Out:
# 27

# %% [markdown]
# Какой процент людей выжил (на основании среза данных)

# %%
print('Survived: {}%'.format(round(df['Survived'].mean()*100,2)))
# Out:
# Survived: 29.41%

# %%
# преобразование в Series
titanic_series = pd.Series(df['Cabin'])
type(titanic_series)
# Out:
# pandas.core.series.Series

# %%
# размерность датафрейма
df.shape
# Out:
# (34, 12)

# %% [markdown]
# Комбинация различных методов

# %%
df.iloc[0:5].rename(index=math.sqrt)
# Out:
#            PassengerId  Survived  Pclass  \
# 27.946377          782         1       1
# 27.964263          783         0       1
# 27.982137          784         0       3
# 28.000000          785         0       3
# 28.017851          786         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 27.946377  Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0      1
# 27.964263                     Long, Mr. Milton Clyde    male  29.0      0
# 27.982137                     Johnston, Mr. Andrew G    male   NaN      1
# 28.000000                           Ali, Mr. William    male  25.0      0
# 28.017851         Harmer, Mr. Abraham (David Lishin)    male  25.0      0
#
#            Parch              Ticket   Fare Cabin Embarked
# 27.946377      0               17474  57.00   B20        S
# 27.964263      0              113501  30.00    D6        S
# 27.982137      2          W./C. 6607  23.45   NaN        S
# 28.000000      0  SOTON/O.Q. 3101312   7.05   NaN        S
# 28.017851      0              374887   7.25   NaN        S

# %%
df['Age'].mean()
# Out:
# 26.297333333333334

# %% [markdown]
# Как влияет пол на выживание?

# %%
df_survived = df[df.Survived==1]
print(df_survived.groupby('Sex')['Name'].count())
# Out:
# Sex
# female    6
# male      4
# Name: Name, dtype: int64

# %% [markdown]
# Влияние класса на выживаемость

# %%
survived_by_class = df.groupby('Pclass').agg(['count', sum])['Survived']
survived_by_class_percent = survived_by_class['sum'] / survived_by_class['count'] * 100
result = pd.concat([survived_by_class, survived_by_class_percent], axis=1)
result.columns = ['Count','Sum','Survive %']
result
# Out:
#         Count  Sum  Survive %
# Pclass
# 1           8    4  50.000000
# 2           6    1  16.666667
# 3          20    5  25.000000
