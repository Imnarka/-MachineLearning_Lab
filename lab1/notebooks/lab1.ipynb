# %%
import os
import pandas as pd
import math

# %%
OPTION = 23
df = pd.read_csv(os.path.join(os.path.abspath('..'), './data/Data_laba_1_ML.csv')).iloc[34 * (OPTION - 1): OPTION * 34]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 748          749         0       1
# 749          750         0       3
# 750          751         1       2
# 751          752         1       3
# 752          753         0       3
# 753          754         0       3
# 754          755         1       2
# 755          756         1       2
# 756          757         0       3
# 757          758         0       2
# 758          759         0       3
# 759          760         1       1
# 760          761         0       3
# 761          762         0       3
# 762          763         1       3
# 763          764         1       1
# 764          765         0       3
# 765          766         1       1
# 766          767         0       1
# 767          768         0       3
# 768          769         0       3
# 769          770         0       3
# 770          771         0       3
# 771          772         0       3
# 772          773         0       2
# 773          774         0       3
# 774          775         1       2
# 775          776         0       3
# 776          777         0       3
# 777          778         1       3
# 778          779         0       3
# 779          780         1       1
# 780          781         1       3
# 781          782         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 748                          Marvin, Mr. Daniel Warner    male  19.00      1
# 749                            Connaghton, Mr. Michael    male  31.00      0
# 750                                  Wells, Miss. Joan  female   4.00      1
# 751                                Moor, Master. Meier    male   6.00      0
# 752                   Vande Velde, Mr. Johannes Joseph    male  33.00      0
# 753                                 Jonkoff, Mr. Lalio    male  23.00      0
# 754                   Herman, Mrs. Samuel (Jane Laver)  female  48.00      1
# 755                          Hamalainen, Master. Viljo    male   0.67      1
# 756                       Carlsson, Mr. August Sigfrid    male  28.00      0
# 757                           Bailey, Mr. Percy Andrew    male  18.00      0
# 758                       Theobald, Mr. Thomas Leonard    male  34.00      0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.00      0
# 760                                 Garfirth, Mr. John    male    NaN      0
# 761                     Nirva, Mr. Iisakki Antino Aijo    male  41.00      0
# 762                              Barah, Mr. Hanna Assi    male  20.00      0
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.00      1
# 764                             Eklund, Mr. Hans Linus    male  16.00      0
# 765               Hogeboom, Mrs. John C (Anna Andrews)  female  51.00      1
# 766                          Brewe, Dr. Arthur Jackson    male    NaN      0
# 767                                 Mangan, Miss. Mary  female  30.50      0
# 768                                Moran, Mr. Daniel J    male    NaN      1
# 769                   Gronnestad, Mr. Daniel Danielsen    male  32.00      0
# 770                             Lievens, Mr. Rene Aime    male  24.00      0
# 771                            Jensen, Mr. Niels Peder    male  48.00      0
# 772                                  Mack, Mrs. (Mary)  female  57.00      0
# 773                                    Elias, Mr. Dibo    male    NaN      0
# 774              Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.00      1
# 775            Myhrman, Mr. Pehr Fabian Oliver Malkolm    male  18.00      0
# 776                                   Tobin, Mr. Roger    male    NaN      0
# 777                      Emanuel, Miss. Virginia Ethel  female   5.00      0
# 778                            Kilgannon, Mr. Thomas J    male    NaN      0
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.00      0
# 780                               Ayoub, Miss. Banoura  female  13.00      0
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.00      1
#
#      Parch            Ticket      Fare    Cabin Embarked
# 748      0            113773   53.1000      D30        S
# 749      0            335097    7.7500      NaN        Q
# 750      1             29103   23.0000      NaN        S
# 751      1            392096   12.4750     E121        S
# 752      0            345780    9.5000      NaN        S
# 753      0            349204    7.8958      NaN        S
# 754      2            220845   65.0000      NaN        S
# 755      1            250649   14.5000      NaN        S
# 756      0            350042    7.7958      NaN        S
# 757      0             29108   11.5000      NaN        S
# 758      0            363294    8.0500      NaN        S
# 759      0            110152   86.5000      B77        S
# 760      0            358585   14.5000      NaN        S
# 761      0  SOTON/O2 3101272    7.1250      NaN        S
# 762      0              2663    7.2292      NaN        C
# 763      2            113760  120.0000  B96 B98        S
# 764      0            347074    7.7750      NaN        S
# 765      0             13502   77.9583      D11        S
# 766      0            112379   39.6000      NaN        C
# 767      0            364850    7.7500      NaN        Q
# 768      0            371110   24.1500      NaN        Q
# 769      0              8471    8.3625      NaN        S
# 770      0            345781    9.5000      NaN        S
# 771      0            350047    7.8542      NaN        S
# 772      0       S.O./P.P. 3   10.5000      E77        S
# 773      0              2674    7.2250      NaN        C
# 774      3             29105   23.0000      NaN        S
# 775      0            347078    7.7500      NaN        S
# 776      0            383121    7.7500      F38        Q
# 777      0            364516   12.4750      NaN        S
# 778      0             36865    7.7375      NaN        Q
# 779      1             24160  211.3375       B3        S
# 780      0              2687    7.2292      NaN        C
# 781      0             17474   57.0000      B20        S

# %% [markdown]
# Вывести первые N строк датафрейма:

# %%
df.head(n=2) # по умолчанию 5
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 748          749         0       1  Marvin, Mr. Daniel Warner  male  19.0
# 749          750         0       3    Connaghton, Mr. Michael  male  31.0
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked
# 748      1      0  113773  53.10   D30        S
# 749      0      0  335097   7.75   NaN        Q

# %% [markdown]
# Вывести "статискиу" датафрейма: среднее значение, стандартное отклонение, минимум и максимум, верхние значения первого и третьего квартиля и медиану по каждому столбцу

# %%
df.describe()
# Out:
#        PassengerId   Survived     Pclass        Age      SibSp      Parch  \
# count    34.000000  34.000000  34.000000  28.000000  34.000000  34.000000
# mean    765.500000   0.382353   2.411765  27.970357   0.264706   0.323529
# std       9.958246   0.493270   0.820851  15.673940   0.447811   0.726994
# min     749.000000   0.000000   1.000000   0.670000   0.000000   0.000000
# 25%     757.250000   0.000000   2.000000  17.750000   0.000000   0.000000
# 50%     765.500000   0.000000   3.000000  29.250000   0.000000   0.000000
# 75%     773.750000   1.000000   3.000000  37.250000   0.750000   0.000000
# max     782.000000   1.000000   3.000000  57.000000   1.000000   3.000000
#
#              Fare
# count   34.000000
# mean    29.143382
# std     42.387526
# min      7.125000
# 25%      7.756250
# 50%     10.000000
# 75%     23.862500
# max    211.337500

# %% [markdown]
# Запрос с условными операторами

# %%
df.query('Survived > 0')
# Out:
#      PassengerId  Survived  Pclass  \
# 750          751         1       2
# 751          752         1       3
# 754          755         1       2
# 755          756         1       2
# 759          760         1       1
# 762          763         1       3
# 763          764         1       1
# 765          766         1       1
# 774          775         1       2
# 777          778         1       3
# 779          780         1       1
# 780          781         1       3
# 781          782         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 750                                  Wells, Miss. Joan  female   4.00      1
# 751                                Moor, Master. Meier    male   6.00      0
# 754                   Herman, Mrs. Samuel (Jane Laver)  female  48.00      1
# 755                          Hamalainen, Master. Viljo    male   0.67      1
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.00      0
# 762                              Barah, Mr. Hanna Assi    male  20.00      0
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.00      1
# 765               Hogeboom, Mrs. John C (Anna Andrews)  female  51.00      1
# 774              Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.00      1
# 777                      Emanuel, Miss. Virginia Ethel  female   5.00      0
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.00      0
# 780                               Ayoub, Miss. Banoura  female  13.00      0
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.00      1
#
#      Parch  Ticket      Fare    Cabin Embarked
# 750      1   29103   23.0000      NaN        S
# 751      1  392096   12.4750     E121        S
# 754      2  220845   65.0000      NaN        S
# 755      1  250649   14.5000      NaN        S
# 759      0  110152   86.5000      B77        S
# 762      0    2663    7.2292      NaN        C
# 763      2  113760  120.0000  B96 B98        S
# 765      0   13502   77.9583      D11        S
# 774      3   29105   23.0000      NaN        S
# 777      0  364516   12.4750      NaN        S
# 779      1   24160  211.3375       B3        S
# 780      0    2687    7.2292      NaN        C
# 781      0   17474   57.0000      B20        S

# %% [markdown]
# Группировка по столбцам c аггрегированием

# %%
df.groupby('Embarked').agg(sum).loc[:,"Survived"]
# Out:
# /tmp/ipykernel_1217/3638000176.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Embarked').agg(sum).loc[:,"Survived"]
# Embarked
# C     2
# Q     0
# S    11
# Name: Survived, dtype: int64

# %% [markdown]
# Выборки данных

# %%
print(df.iloc[4:6, 0:2]) # выбор по поизции
print(df.loc[:, 'Pclass':'Name']) # выбор по метке
# Out:
#      PassengerId  Survived
# 752          753         0
# 753          754         0
#      Pclass                                               Name
# 748       1                          Marvin, Mr. Daniel Warner
# 749       3                            Connaghton, Mr. Michael
# 750       2                                  Wells, Miss. Joan
# 751       3                                Moor, Master. Meier
# 752       3                   Vande Velde, Mr. Johannes Joseph
# 753       3                                 Jonkoff, Mr. Lalio
# 754       2                   Herman, Mrs. Samuel (Jane Laver)
# 755       2                          Hamalainen, Master. Viljo
# 756       3                       Carlsson, Mr. August Sigfrid
# 757       2                           Bailey, Mr. Percy Andrew
# 758       3                       Theobald, Mr. Thomas Leonard
# 759       1  Rothes, the Countess. of (Lucy Noel Martha Dye...
# 760       3                                 Garfirth, Mr. John
# 761       3                     Nirva, Mr. Iisakki Antino Aijo
# 762       3                              Barah, Mr. Hanna Assi
# 763       1          Carter, Mrs. William Ernest (Lucile Polk)
# 764       3                             Eklund, Mr. Hans Linus
# 765       1               Hogeboom, Mrs. John C (Anna Andrews)
# 766       1                          Brewe, Dr. Arthur Jackson
# 767       3                                 Mangan, Miss. Mary
# 768       3                                Moran, Mr. Daniel J
# 769       3                   Gronnestad, Mr. Daniel Danielsen
# 770       3                             Lievens, Mr. Rene Aime
# 771       3                            Jensen, Mr. Niels Peder
# 772       2                                  Mack, Mrs. (Mary)
# 773       3                                    Elias, Mr. Dibo
# 774       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 775       3            Myhrman, Mr. Pehr Fabian Oliver Malkolm
# 776       3                                   Tobin, Mr. Roger
# 777       3                      Emanuel, Miss. Virginia Ethel
# 778       3                            Kilgannon, Mr. Thomas J
# 779       1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
# 780       3                               Ayoub, Miss. Banoura
# 781       1          Dick, Mrs. Albert Adrian (Vera Gillespie)

# %% [markdown]
# Индексация

# %%
print(df.index)
sample_series = df['PassengerId'].head(n = 3)
sample_series.index = ["zero", "one", "two"]
sample_series
# Out:
# RangeIndex(start=748, stop=782, step=1)
# zero    749
# one     750
# two     751
# Name: PassengerId, dtype: int64

# %% [markdown]
# Транспонирование

# %%
df.T
# Out:
#                                    748                      749  \
# PassengerId                        749                      750
# Survived                             0                        0
# Pclass                               1                        3
# Name         Marvin, Mr. Daniel Warner  Connaghton, Mr. Michael
# Sex                               male                     male
# Age                               19.0                     31.0
# SibSp                                1                        0
# Parch                                0                        0
# Ticket                          113773                   335097
# Fare                              53.1                     7.75
# Cabin                              D30                      NaN
# Embarked                             S                        Q
#
#                            750                  751  \
# PassengerId                751                  752
# Survived                     1                    1
# Pclass                       2                    3
# Name         Wells, Miss. Joan  Moor, Master. Meier
# Sex                     female                 male
# Age                        4.0                  6.0
# SibSp                        1                    0
# Parch                        1                    1
# Ticket                   29103               392096
# Fare                      23.0               12.475
# Cabin                      NaN                 E121
# Embarked                     S                    S
#
#                                           752                 753  \
# PassengerId                               753                 754
# Survived                                    0                   0
# Pclass                                      3                   3
# Name         Vande Velde, Mr. Johannes Joseph  Jonkoff, Mr. Lalio
# Sex                                      male                male
# Age                                      33.0                23.0
# SibSp                                       0                   0
# Parch                                       0                   0
# Ticket                                 345780              349204
# Fare                                      9.5              7.8958
# Cabin                                     NaN                 NaN
# Embarked                                    S                   S
#
#                                           754                        755  \
# PassengerId                               755                        756
# Survived                                    1                          1
# Pclass                                      2                          2
# Name         Herman, Mrs. Samuel (Jane Laver)  Hamalainen, Master. Viljo
# Sex                                    female                       male
# Age                                      48.0                       0.67
# SibSp                                       1                          1
# Parch                                       2                          1
# Ticket                                 220845                     250649
# Fare                                     65.0                       14.5
# Cabin                                     NaN                        NaN
# Embarked                                    S                          S
#
#                                       756                       757  ...  \
# PassengerId                           757                       758  ...
# Survived                                0                         0  ...
# Pclass                                  3                         2  ...
# Name         Carlsson, Mr. August Sigfrid  Bailey, Mr. Percy Andrew  ...
# Sex                                  male                      male  ...
# Age                                  28.0                      18.0  ...
# SibSp                                   0                         0  ...
# Parch                                   0                         0  ...
# Ticket                             350042                     29108  ...
# Fare                               7.7958                      11.5  ...
# Cabin                                 NaN                       NaN  ...
# Embarked                                S                         S  ...
#
#                            772              773  \
# PassengerId                773              774
# Survived                     0                0
# Pclass                       2                3
# Name         Mack, Mrs. (Mary)  Elias, Mr. Dibo
# Sex                     female             male
# Age                       57.0              NaN
# SibSp                        0                0
# Parch                        0                0
# Ticket             S.O./P.P. 3             2674
# Fare                      10.5            7.225
# Cabin                      E77              NaN
# Embarked                     S                C
#
#                                                774  \
# PassengerId                                    775
# Survived                                         1
# Pclass                                           2
# Name         Hocking, Mrs. Elizabeth (Eliza Needs)
# Sex                                         female
# Age                                           54.0
# SibSp                                            1
# Parch                                            3
# Ticket                                       29105
# Fare                                          23.0
# Cabin                                          NaN
# Embarked                                         S
#
#                                                  775               776  \
# PassengerId                                      776               777
# Survived                                           0                 0
# Pclass                                             3                 3
# Name         Myhrman, Mr. Pehr Fabian Oliver Malkolm  Tobin, Mr. Roger
# Sex                                             male              male
# Age                                             18.0               NaN
# SibSp                                              0                 0
# Parch                                              0                 0
# Ticket                                        347078            383121
# Fare                                            7.75              7.75
# Cabin                                            NaN               F38
# Embarked                                           S                 Q
#
#                                        777                      778  \
# PassengerId                            778                      779
# Survived                                 1                        0
# Pclass                                   3                        3
# Name         Emanuel, Miss. Virginia Ethel  Kilgannon, Mr. Thomas J
# Sex                                 female                     male
# Age                                    5.0                      NaN
# SibSp                                    0                        0
# Parch                                    0                        0
# Ticket                              364516                    36865
# Fare                                12.475                   7.7375
# Cabin                                  NaN                      NaN
# Embarked                                 S                        Q
#
#                                                            779  \
# PassengerId                                                780
# Survived                                                     1
# Pclass                                                       1
# Name         Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
# Sex                                                     female
# Age                                                       43.0
# SibSp                                                        0
# Parch                                                        1
# Ticket                                                   24160
# Fare                                                  211.3375
# Cabin                                                       B3
# Embarked                                                     S
#
#                               780                                        781
# PassengerId                   781                                        782
# Survived                        1                                          1
# Pclass                          3                                          1
# Name         Ayoub, Miss. Banoura  Dick, Mrs. Albert Adrian (Vera Gillespie)
# Sex                        female                                     female
# Age                          13.0                                       17.0
# SibSp                           0                                          1
# Parch                           0                                          0
# Ticket                       2687                                      17474
# Fare                       7.2292                                       57.0
# Cabin                         NaN                                        B20
# Embarked                        C                                          S
#
# [12 rows x 34 columns]

# %%
# сколько пропущенных значений в столбце Cabin?
print(df['Cabin'].isnull().sum())
# Out:
# 25

# %% [markdown]
# Какой процент людей выжил (на основании среза данных)

# %%
print('Survived: {}%'.format(round(df['Survived'].mean()*100,2)))
# Out:
# Survived: 38.24%

# %%
# преобразование в Series
titanic_series = pd.Series(df['Cabin'])
print(type(df['Cabin']))
print(type(titanic_series))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
# размерность датафрейма
df.shape
# Out:
# (34, 12)

# %% [markdown]
# Комбинация различных методов

# %%
df.iloc[0:5].rename(index=math.sqrt)
# Out:
#            PassengerId  Survived  Pclass                              Name  \
# 27.349589          749         0       1         Marvin, Mr. Daniel Warner
# 27.367864          750         0       3           Connaghton, Mr. Michael
# 27.386128          751         1       2                 Wells, Miss. Joan
# 27.404379          752         1       3               Moor, Master. Meier
# 27.422618          753         0       3  Vande Velde, Mr. Johannes Joseph
#
#               Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 27.349589    male  19.0      1      0  113773  53.100   D30        S
# 27.367864    male  31.0      0      0  335097   7.750   NaN        Q
# 27.386128  female   4.0      1      1   29103  23.000   NaN        S
# 27.404379    male   6.0      0      1  392096  12.475  E121        S
# 27.422618    male  33.0      0      0  345780   9.500   NaN        S

# %%
df['Age'].mean()
# Out:
# 27.970357142857146

# %% [markdown]
# Как влияет пол на выживание?

# %%
df_survived = df[df.Survived==1]
print(df_survived.groupby('Sex')['Survived'].count())
# Out:
# Sex
# female    10
# male       3
# Name: Survived, dtype: int64

# %% [markdown]
# Влияние класса на выживаемость

# %%
survived_by_class = df.groupby('Pclass').agg(['count', 'sum'])['Survived'] # считаем кол-во всех и сумму уже выживших
survived_by_class_percent = survived_by_class['sum'] / survived_by_class['count'] * 100
result = pd.concat([survived_by_class, survived_by_class_percent], axis=1)
result.columns = ['Count','Sum','Survive %']
result
# Out:
#         Count  Sum  Survive %
# Pclass
# 1           7    5  71.428571
# 2           6    4  66.666667
# 3          21    4  19.047619
